# %%
import os
os.chdir('..')
print(os.getcwd())

# %%
from dotenv import load_dotenv
environment = "local"
print("successfully loaded env file: ", load_dotenv(f"./env/.env.{environment}", override=True))

# %%
# private library imports
from spotify_client.entities import User

# %%
config_path = os.path.join(os.environ["TRACKS_DATABASE_FOLDER"], "latest_config.json")

with open(config_path, "r") as f:
    user = User.model_validate_json(f.read())

# these variables will be used by spotipy
os.environ["SPOTIPY_CLIENT_ID"] = user.auth.client_id
os.environ["SPOTIPY_CLIENT_SECRET"] = user.auth.client_secret
os.environ["SPOTIPY_REDIRECT_URI"] = user.auth.redirect_uri

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

sp = spotipy.Spotify(auth_manager=SpotifyOAuth())

# %%
playlist = sp.playlist("https://open.spotify.com/playlist/5M7xLCQTYJL0lbKIrUn3a4?si=92c980c822f3462a")
playlist["name"]
